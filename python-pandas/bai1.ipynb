# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")
print(df.isnull().sum())
age_min = df['Age'].min()
age_max = df['Age'].max()
df['Age'] = df['Age'].apply(
    lambda x: np.random.randint(age_min, age_max+1) if pd.isnull(x) else x
)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# print(df.isnull().sum())
print(df['Cabin'].count())
print(df['PassengerId'].count())
# Out:
# 204
# 891

# %%
df1 = pd.read_csv("test.csv")
print(df1.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
