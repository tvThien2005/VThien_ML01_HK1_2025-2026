# %% [markdown]
# ## Import thư viện

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('pl_15-16.csv')
train_data.head()
# Out:
#    Unnamed: 0                Name    Position  Appearances  Clean sheets  \
# 0           0     Rolando Aarons   Midfielder           10           NaN
# 1           1         Almen Abdi   Midfielder           32           NaN
# 2           2  Abdul Rahman Baba     Defender           15           2.0
# 3           3        Mehdi Abeid   Midfielder            0           NaN
# 4           4      Tammy Abraham      Forward            2           NaN
#
#    Goals conceded  Tackles Tackle success %  Last man tackles  Blocked shots  \
# 0             NaN     13.0              77%               NaN            0.0
# 1             NaN     83.0              78%               NaN           10.0
# 2            13.0     47.0              83%               0.0            1.0
# 3             NaN      0.0               0%               NaN            0.0
# 4             NaN      0.0              NaN               NaN            1.0
#
# ...

# %% [markdown]
# ## kiểm tra dữ liệu bị thiếu

# %%
for col in train_data.columns:
    missing = train_data[col].isnull().sum()
    if missing > 0:
        print(f"{col}: {missing} missing values: {missing/train_data.shape[0]*100:.2f}%")
# Out:
# Clean sheets: 435 missing values: 57.46%
# Goals conceded: 435 missing values: 57.46%
# Tackles: 76 missing values: 10.04%
# Tackle success %: 243 missing values: 32.10%
# Last man tackles: 511 missing values: 67.50%
# Blocked shots: 76 missing values: 10.04%
# Interceptions: 76 missing values: 10.04%
# Clearances: 76 missing values: 10.04%
# Headed Clearance: 76 missing values: 10.04%
# Clearances off line: 511 missing values: 67.50%
# Recoveries: 243 missing values: 32.10%
# Duels won: 243 missing values: 32.10%
# Duels lost: 243 missing values: 32.10%
# Successful 50/50s: 243 missing values: 32.10%
# Aerial battles won: 243 missing values: 32.10%
# Aerial battles lost: 243 missing values: 32.10%
# Own goals: 435 missing values: 57.46%
# Errors leading to goal: 167 missing values: 22.06%
# Big chances created: 76 missing values: 10.04%
# Crosses: 76 missing values: 10.04%
# Cross accuracy %: 243 missing values: 32.10%
# Through balls: 243 missing values: 32.10%
# ...
